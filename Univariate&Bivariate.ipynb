# %%
import pandas as pd

# %%
df=pd.read_csv('preCovidStudentSurvey.csv')

# %%
df
# Out:
#       Age of Subject  Time spent on Online Class  \
# 0                 21                         2.0
# 1                 21                         0.0
# 2                 20                         7.0
# 3                 20                         3.0
# 4                 21                         3.0
# ...              ...                         ...
# 1177              12                         3.0
# 1178              14                         6.0
# 1179              13                         4.0
# 1180              14                         5.0
# 1181              13                         5.0
#
#      Rating of Online Class experience Medium for online class  \
# 0                                 Good          Laptop/Desktop
# 1                            Excellent              Smartphone
# 2                            Very poor          Laptop/Desktop
# 3                            Very poor              Smartphone
# ...

# %% [markdown]
# # Inferential Analysis

# %% [markdown]
# # 1. How many students health is affected

# %%
df['Health issue during lockdown'].value_counts()
# Out:
# Health issue during lockdown
# NO     1021
# YES     161
# Name: count, dtype: int64

# %% [markdown]
# # 161 students health is affected during lockdown

# %% [markdown]
# # 2)Find the reason for health issues from the dataset?

# %%
health_df=pd.DataFrame(df[df['Health issue during lockdown'] =='YES'])
health_df.sort_values(by='Time spent on fitness',ascending=False)
health_df.head(10)
# Out:
#     Age of Subject  Time spent on Online Class  \
# 5               21                         0.0
# 7               19                         2.0
# 9               20                         0.0
# 11              21                         1.0
# 12              21                         3.0
# 26              21                         4.0
# 30              19                         4.0
# 33              22                         5.0
# 42              20                         7.0
# 47              20                         2.0
#
#    Rating of Online Class experience Medium for online class  \
# 5                          Very poor              Smartphone
# 7                          Very poor                  Tablet
# 9                          Very poor          Laptop/Desktop
# 11                         Very poor          Laptop/Desktop
# 12                           Average          Laptop/Desktop
# 26                         Very poor          Laptop/Desktop
# ...

# %% [markdown]
# # Students who spend low time for fitness (<=1 hour) are affected physically

# %% [markdown]
# # 3) What kind of relation between Time spent for fitness and Time spent for sleep?

# %%
df.corr(numeric_only=True)
# Out:
#                             Age of Subject  Time spent on Online Class  \
# Age of Subject                    1.000000                   -0.229569
# Time spent on Online Class       -0.229569                    1.000000
# Time spent on self study          0.027228                    0.142616
# Time spent on fitness            -0.066037                   -0.021437
# Time spent on sleep              -0.099760                   -0.178849
# Time spent on social media        0.156363                   -0.130193
# Time spent on TV                 -0.083699                   -0.017315
# Number of meals per day          -0.006294                    0.021839
#
#                             Time spent on self study  Time spent on fitness  \
# Age of Subject                              0.027228              -0.066037
# Time spent on Online Class                  0.142616              -0.021437
# Time spent on self study                    1.000000               0.027828
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 2))
plt.scatter(df['Time spent on fitness'], df['Time spent on sleep'])
plt.xlabel('Time spent on fitness')
plt.ylabel('Time spent on sleep')
plt.show()

# %% [markdown]
# # Relation between Time spent on fitness and Time spent on sleep is in negative correlation ( One column increases and other decreases)  -0.043887

# %% [markdown]
# # 4) Which social media is getting maximum usage ?

# %%
avg_socialMedia = df.groupby('Prefered social media platform')['Time spent on social media'].mean().sort_values()
df_socialMedia=pd.DataFrame(avg_socialMedia)

# %%
df_socialMedia
# Out:
#                                 Time spent on social media
# Prefered social media platform
# Not Interested                                    0.500000
# Others                                            1.833333
# WhatsApp                                          1.896736
# Linkedin                                          2.036885
# Youtube                                           2.180573
# Facebook                                          2.663462
# Twitter                                           2.696429
# Instagram                                         2.795739
# Snapchat                                          3.125000

# %%
import seaborn as sns
sns.barplot(x = "Prefered social media platform", y = "Time spent on social media", data = df_socialMedia)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Students are spending more time in Snapshot when compared to other platform

# %% [markdown]
# # 5)Which Medium for online class is getting less Usage?

# %%
medium_df= df.groupby('Medium for online class')['Time spent on Online Class'].mean().sort_values()
medium_df
# Out:
# Medium for online class
# Not Interested                  1.211765
# Smartphone                      3.068831
# Laptop/Desktop                  3.431101
# Smartphone or Laptop/Desktop    4.200000
# Tablet                          4.297297
# Any Gadget                      5.000000
# Name: Time spent on Online Class, dtype: float64

# %% [markdown]
# # 6)Test the Analysis of Variance between Time spent on fitness and Time spent on sleep at signifance level 5%. Make decision using Hypothesis Testing)

# %%
import scipy.stats as stats

stats.f_oneway(df['Time spent on fitness'],df['Time spent on sleep'])
# Out:
# F_onewayResult(statistic=20102.5282340282, pvalue=0.0)

# %% [markdown]
# STATEMENT : Time spent on fitness and Time spent on sleep are significantly different
# NULL HYPO : There is not significant different in between Time spent on fitness , Time spent on sleep
# ALTER HYPO : There is significant different in between Time spent on fitness , Time spent on sleep
# SOLUTION : Rule : p<0.05 reject null hypo 0.00<0.05 true so accept alter hypo

# %% [markdown]
# # 7) What student missed more during pandemic

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Assuming raw_df is your DataFrame containing the column you want to visualize
column_name = 'What you miss the most'  # Replace 'Cuisine' with your column name

# Extract the column from the DataFrame
column_data = df[column_name]

# Using word cloud the entire column is converted into single string. 
# Convert the column to a single string
text_data = ' '.join(map(str, column_data))

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)

# Plot the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off axis labels
plt.show()

# %% [markdown]
# # They missed school and college, roaming around, friends and relatives.
